# %%
import pandas as pd
dados = pd.read_csv("FIFA19.csv")

# %%
dados.loc[dados["Nationality"]=="Spain"]
# Out:
#        Unnamed: 0                 Name  Age Nationality  Overall  Potential  \
# 3               3               De Gea   27       Spain       91         93
# 8               8         Sergio Ramos   32       Spain       91         91
# 13             13          David Silva   32       Spain       90         90
# 20             20      Sergio Busquets   29       Spain       89         89
# 30             30                 Isco   26       Spain       88         91
# ...           ...                  ...  ...         ...      ...        ...
# 16987       17043        Cristian Arco   23       Spain       55         61
# 17014       17070               Taliby   21       Spain       55         64
# 17060       17116         Víctor Gómez   18       Spain       55         73
# 17217       17274            Hugo Díaz   21       Spain       55         70
# 17866       17926  Carlos Mendes Gomes   19       Spain       51         61
#
# ...

# %%
dados.sort_values("Age")
# Out:
#        Unnamed: 0            Name  Age        Nationality  Overall  Potential  \
# 18146       18206       G. Nugent   16            England       46         66
# 18106       18166        N. Ayéva   16             Sweden       48         72
# 17916       17976       M. Larsen   16            Denmark       51         71
# 18102       18162    T. Gundelund   16            Denmark       48         66
# 12491       12496  Pelayo Morilla   16              Spain       63         81
# ...           ...             ...  ...                ...      ...        ...
# 4228         4228        B. Nivet   41             France       71         71
# 10541       10545     S. Narazaki   42              Japan       65         65
# 17666       17726       T. Warner   44  Trinidad & Tobago       53         53
# 18123       18183   K. Pilkington   44            England       48         48
# 4741         4741        O. Pérez   45             Mexico       71         71
#
# ...
