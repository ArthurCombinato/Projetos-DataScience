# %%
import pandas as pd
dados = pd.read_csv("house.csv")

# %%
dados
# Out:
#                  Suburb           Address  ...  Distance                 CouncilArea
# 0            Abbotsford     49 Lithgow St  ...       3.0          Yarra City Council
# 1            Abbotsford     59A Turner St  ...       3.0          Yarra City Council
# 2            Abbotsford     119B Yarra St  ...       3.0          Yarra City Council
# 3            Aberfeldie        68 Vida St  ...       7.5  Moonee Valley City Council
# 4          Airport West  92 Clydesdale Rd  ...      10.4  Moonee Valley City Council
# ...                 ...               ...  ...       ...                         ...
# 63018     Roxburgh Park         3 Carr Pl  ...      20.6           Hume City Council
# 63019     Roxburgh Park       9 Parker Ct  ...      20.6           Hume City Council
# 63020     Roxburgh Park    5 Parkinson Wy  ...      20.6           Hume City Council
# 63021        Thomastown    3/1 Travers St  ...      15.3     Whittlesea City Council
# ...

# %%
dados = dados.loc[dados["Rooms"] == 3]
dados.sort_values("Price")
# Out:
#                Suburb  ...               CouncilArea
# 20532        Brighton  ...      Bayside City Council
# 44551  Meadow Heights  ...         Hume City Council
# 35971    Melton South  ...       Melton City Council
# 20431    Melton South  ...       Melton City Council
# 28760          Melton  ...       Melton City Council
# ...               ...  ...                       ...
# 62976        Werribee  ...      Wyndham City Council
# 62996      Wonga Park  ...   Manningham City Council
# 63001    Wyndham Vale  ...      Wyndham City Council
# 63008      Yarraville  ...  Maribyrnong City Council
# 63021      Thomastown  ...   Whittlesea City Council
#
# [27950 rows x 13 columns]
