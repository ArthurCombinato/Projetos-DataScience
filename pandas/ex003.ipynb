# %%
import pandas as pd
dados = pd.read_csv("FIFA19.csv")

# %%
dados["total"] = dados["Acceleration"] + dados["Agility"] + dados["Reactions"]

# %%
dados["total"]
# Out:
# 0        277.0
# 1        272.0
# 2        284.0
# 3        207.0
# 4        248.0
#          ...
# 18142    163.0
# 18143    119.0
# 18144    167.0
# 18145    134.0
# 18146    163.0
# Name: total, Length: 18147, dtype: float64

# %%
dados.sort_values("total")
# Out:
#        Unnamed: 0          Name  Age     Nationality  Overall  Potential  \
# 17625       17685     Lee Yunoh   19  Korea Republic       53         58
# 18067       18127    N. Stephan   17         Germany       49         67
# 18138       18198    J. Livesey   18         England       47         70
# 17747       17807  J. Brendieck   19         Germany       52         66
# 17808       17868    A. Czaplak   21          Poland       52         60
# ...           ...           ...  ...             ...      ...        ...
# 50             50    D. Mertens   31         Belgium       87         87
# 26             26      M. Salah   26           Egypt       88         89
# 0               0      L. Messi   31       Argentina       94         94
# 5               5     E. Hazard   27         Belgium       91         91
# 2               2     Neymar Jr   26          Brazil       92         93
#
#                         Club    Value   Wage Preferred Foot  ...  \
# ...

# %%
dados = dados[["Name", "total"]]
dados.sort_values("total", ascending = False)
# Out:
#                Name  total
# 2         Neymar Jr  284.0
# 5         E. Hazard  279.0
# 0          L. Messi  277.0
# 26         M. Salah  276.0
# 60      R. Sterling  275.0
# ...             ...    ...
# 17808    A. Czaplak   77.0
# 17747  J. Brendieck   77.0
# 18138    J. Livesey   76.0
# 18067    N. Stephan   74.0
# 17625     Lee Yunoh   71.0
#
# [18147 rows x 2 columns]

# %%
dados.head()
# Out:
#                 Name  total
# 0           L. Messi  277.0
# 1  Cristiano Ronaldo  272.0
# 2          Neymar Jr  284.0
# 3             De Gea  207.0
# 4       K. De Bruyne  248.0

# %%
dados.to_csv("dados1.csv", index= False)
