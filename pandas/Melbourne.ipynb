# %%
import pandas as pd
import re

# %%
df = pd.read_csv("house.csv")

# %%
filter1 = df.loc[(df['Rooms'] == 3) & (df['Type'] == 'h')]
filter1
# Out:
#               Suburb            Address  Rooms Type      Price Method  \
# 0         Abbotsford      49 Lithgow St      3    h  1490000.0      S
# 1         Abbotsford      59A Turner St      3    h  1220000.0      S
# 2         Abbotsford      119B Yarra St      3    h  1420000.0      S
# 3         Aberfeldie         68 Vida St      3    h  1515000.0      S
# 7       Airport West  1/26 Highridge Cr      3    h   715000.0     SP
# ...              ...                ...    ...  ...        ...    ...
# 63011        Doveton      12 Scarlet Dr      3    h   595000.0     PI
# 63017        Preston      229 Murray Rd      3    h   808000.0      S
# 63018  Roxburgh Park          3 Carr Pl      3    h   566000.0      S
# 63019  Roxburgh Park        9 Parker Ct      3    h   500000.0      S
# 63020  Roxburgh Park     5 Parkinson Wy      3    h   545000.0      S
#
#         SellerG        Date  Postcode                  Regionname  \
# ...

# %%
filter2 = df.loc[df["Price"] <1000000]
filter2
# Out:
#               Suburb             Address  Rooms Type     Price Method  \
# 4       Airport West    92 Clydesdale Rd      2    h  670000.0      S
# 5       Airport West        4/32 Earl St      2    t  530000.0      S
# 6       Airport West      3/74 Hawker St      2    u  540000.0      S
# 7       Airport West   1/26 Highridge Cr      3    h  715000.0     SP
# 10            Albion  3/15 Drummartin St      3    u  515000.0      S
# ...              ...                 ...    ...  ...       ...    ...
# 63016      Frankston      4/34 Petrie St      2    u  347700.0     SP
# 63017        Preston       229 Murray Rd      3    h  808000.0      S
# 63018  Roxburgh Park           3 Carr Pl      3    h  566000.0      S
# 63019  Roxburgh Park         9 Parker Ct      3    h  500000.0      S
# 63020  Roxburgh Park      5 Parkinson Wy      3    h  545000.0      S
#
#        SellerG        Date  Postcode                  Regionname  \
# ...

# %%
filter3 = df.loc[df["Address"].str.contains("Turner st | Turner rd", flags=re.I)]
filter3
# Out:
#            Suburb         Address  Rooms Type      Price Method  SellerG  \
# 4723      Highett    48 Turner Rd      2    h   832000.0      S   Buxton
# 7501      Highett    28 Turner Rd      3    h        NaN     PI     Nick
# 19609     Highett  2/20 Turner Rd      2    u   730000.0     SP   Buxton
# 20717  Langwarrin    49 Turner Rd      4    h        NaN     PI   UFirst
# 39873     Highett   3/6 Turner Rd      3    u        NaN     PI   Buxton
# 41985     Highett   1/6 Turner Rd      4    h   921000.0      S   Buxton
# 45597     Highett  3/15 Turner Rd      2    u   770000.0      S  McGrath
# 53753     Highett   2/4 Turner Rd      2    u   680500.0      S      Ray
# 58707     Highett    22 Turner Rd      3    h  1150000.0     SP   Buxton
#
#              Date  Postcode             Regionname  Propertycount  Distance  \
# 4723    3/09/2017      3190  Southern Metropolitan           4794      16.0
# 7501    4/08/2018      3190  Southern Metropolitan           4794      16.0
# ...
