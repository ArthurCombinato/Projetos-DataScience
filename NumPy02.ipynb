# %%
import numpy as np

# %%
# array 1D
d1 = np.array([1,2,3])
print(d1)
# Out:
# [1 2 3]

# %%
d1.shape
# Out:
# (3,)

# %%
d1.ndim
# Out:
# 1

# %%
d1.dtype
# Out:
# dtype('int64')

# %%
d2 = np.array([[1,2,3],[4,5,6]])
print(d2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
d3 = np.array([[[1,2],[3,4]],[[5,6],[7,8]]])
print(d3)
# Out:
# [[[1 2]
#   [3 4]]
#
#  [[5 6]
#   [7 8]]]
