# %%
import numpy as np

# %%
a = np.array([[2,3,4,5,],[6,7,8,9,]])
print(a)
# Out:
# [[2 3 4 5]
#  [6 7 8 9]]

# %%
print(a[1,2])
# Out:
# 8

# %%
print(a[0,:])
# Out:
# [2 3 4 5]

# %%
print(a[:,2])
# Out:
# [4 8]
